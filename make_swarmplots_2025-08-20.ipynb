# %% [markdown]
# <a href="https://colab.research.google.com/github/Munfred/worm-markers/blob/master/make_swarmplots_2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Looking for C. elegans neuronal markers using CeNGEN data
# By Eduardo da Veiga Beltrame - edaveiga@caltech.edu - https://munfred.com
#
# Code repository: https://github.com/Munfred/worm-markers
#
# This notebook creates interactive "swarm plots" to look for marker genes in C. elegans using the CeNGEN dataset of L4 neurons (http://cengen.org/)
#
# ### Summary
# This is a simple computational workflow for using single cell RNA sequencing (scRNAseq) data to identify promising marker gene candidates in C. elegans. This workflow leverages the scvi-tools package (https://scvi-tools.org), which uses deep learning to create a probabilistic model of gene expression in single cells. The workflow is composed of three steps:
#
# 1) Training the scVI model on scRNAseq data;
#
# 2) Performing differential expression (DE) between the cell type of interest and all other cells;
#
# 3) Visualizing the relative expression levels of top DE genes across all cell types to identify promising candidates with an interactive plot.
#
#
# ### Workflow Description
# In principle, there are only two features that make a “good” marker gene for a given cell type: having high specificity to the cell type of interest and having high expression. We reasoned that these features should be possible by using annotated scRNAseq data that includes the cell types of interest.
#
# By repeatedly sampling each cell, scVI allows the inference of transcript “rates”, corresponding to the fractions of transcripts sampled in a given cell that belong to each gene. This is akin to the normalized gene expression that is used in other scRNAseq processing frameworks. However, it is an inference instead of an empirically estimated value  obtained by for example dividing the number of transcripts sequenced in each cell by the total. We refer to it as the expression rate of a gene or simply expression of a gene.
#
# We conceived the following three step workflow to look for high expression and high specificity genes using scVI:
#
# **i) Train the scVI model to integrate the datasets of interest.**
#
# scVI creates a latent representation of each cell that is independent of cell size or sequencing depth (the number of transcripts seen in that cell) and of batch (which experimental run a sample came from). Thus, cells that are closer in the latent representation should be more biologically similar (that is, express the same genes in similar quantities). The learned latent parameters are conditional on cell batch, and when performing batch correction scVI samples evenly from each batch to calculate results.
#
# **ii) Perform DE on the cells of interest to select top genes by DE probability**
#
# Once the scVI model has been trained, the second step is to select the cells of interest and perform DE using the scVI change mode. To visualize specificity and expression rate on the target cells we can make a scatter plot of the posterior predictive p-value  vs. expression frequency for each gene.
#
# **iii) Visualize the relative expression across all tissues to select marker candidates.**
#
# Once the p-values for each gene are computed, the genes with the lowest p-values can be selected for visualizing their expression in every cell type using a “swarm plot”. This is a vertical scatter plot of the expression frequency on each cell type normalized against the expression in the target cell, repeated for each gene. Then the expression on the cell type of interest is one, and for a highly specific gene it should be close to zero in all other cell types. Inspection of this plot quickly reveals whether there are clear marker gene candidates.
#
#
# <img width="1433" alt="Screen Shot 2021-06-02 at 00 21 08" src="https://user-images.githubusercontent.com/12504176/120440506-7a28a100-c338-11eb-8d40-e7f7e45e6a91.png">

# %%
### Installation and imports


# If running in Colab, navigate to Runtime -> Change runtime type
# and ensure you're using a Python 3 runtime with GPU hardware accelerator
# Installation of scVI in Colab can take several minutes
import sys
IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    # !pip install scvi-tools --quiet
    # !pip install opentsne --quiet
    # !pip install scanpy --quiet

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Control warnings
import warnings; warnings.simplefilter('ignore')

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

import torch
import anndata
from tqdm import tqdm
from umap import UMAP
from openTSNE import TSNE
import scanpy as sc 
import plotly.express as px
import plotly.graph_objects as go
from IPython.display import Image
import scvi
print('You are using scvi-tools version:',scvi.__version__)
# Out:
# You are using scvi-tools version: 1.3.3

# %%
# this cell will download the file taylor2020.h5ad with the C. elegans single cell 
# data from the CeNGEN project. The data is described in the preprint 
# "Molecular topography of an entire nervous system", by Taylor et al 2020
# https://doi.org/10.1016/j.neuron.2018.07.042

# !wget -nc https://github.com/Munfred/wormcells-site/releases/download/taylor2020/taylor2020.h5ad

taylor2020 = anndata.read_h5ad('taylor2020.h5ad')

taylor2020.obs['study']='taylor2020'
taylor2020.obs['experiment']=taylor2020.obs['experiment_code']

adata=taylor2020
display(adata.obs.head(3))
display(adata.var.head(3))
# Out:
# --2025-09-20 22:29:47--  https://github.com/Munfred/wormcells-site/releases/download/taylor2020/taylor2020.h5ad
# Resolving github.com (github.com)... 20.233.83.145
# Connecting to github.com (github.com)|20.233.83.145|:443... connected.
# 301 Moved Permanentlyaiting response...
# Location: https://github.com/Munfred/wormcells-data/releases/download/taylor2020/taylor2020.h5ad [following]
# --2025-09-20 22:29:48--  https://github.com/Munfred/wormcells-data/releases/download/taylor2020/taylor2020.h5ad
# Reusing existing connection to github.com:443.
# 302 Foundest sent, awaiting response...
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/222185132/0b5c6880-5149-11eb-8695-20a4f0843b75?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-09-20T19%3A15%3A54Z&rscd=attachment%3B+filename%3Dtaylor2020.h5ad&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-09-20T18%3A15%3A52Z&ske=2025-09-20T19%3A15%3A54Z&sks=b&skv=2018-11-09&sig=xF7AmaNjYwL8GOZQh4gWXbj2V7Qqu8REDBWk59ErbTw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1ODM5MzI4OCwibmJmIjoxNzU4MzkyOTg4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.wc6RB92hazD_Vz-IC5TiVUBRDOGWS9npp0hyFM0wTws&response-content-disposition=attachment%3B%20filename%3Dtaylor2020.h5ad&response-content-type=application%2Foctet-stream [following]
# --2025-09-20 22:29:48--  https://release-assets.githubusercontent.com/github-production-release-asset/222185132/0b5c6880-5149-11eb-8695-20a4f0843b75?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-09-20T19%3A15%3A54Z&rscd=attachment%3B+filename%3Dtaylor2020.h5ad&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-09-20T18%3A15%3A52Z&ske=2025-09-20T19%3A15%3A54Z&sks=b&skv=2018-11-09&sig=xF7AmaNjYwL8GOZQh4gWXbj2V7Qqu8REDBWk59ErbTw%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc1ODM5MzI4OCwibmJmIjoxNzU4MzkyOTg4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.wc6RB92hazD_Vz-IC5TiVUBRDOGWS9npp0hyFM0wTws&response-content-disposition=attachment%3B%20filename%3Dtaylor2020.h5ad&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 381516791 (364M) [application/octet-stream]
# Saving to: ‘taylor2020.h5ad’
#
# taylor2020.h5ad     100%[===================>] 363.84M  8.07MB/s    in 35s
#
# 2025-09-20 22:30:24 (10.3 MB/s) - ‘taylor2020.h5ad’ saved [381516791/381516791]
#                            dropbox_id  counts experiment_code    cell_type  \
# 1806-ST-1-AAACCTGAGAGACGAA  1806-ST-1      65           Pan-1  Unannotated
# 1806-ST-1-AAACCTGAGGTAAACT  1806-ST-1     367           Pan-1          AVF
# 1806-ST-1-AAACCTGAGGTAGCCA  1806-ST-1    1792           Pan-1          AVH
#
#                                  tissue       study experiment
# 1806-ST-1-AAACCTGAGAGACGAA  Unannotated  taylor2020      Pan-1
# 1806-ST-1-AAACCTGAGGTAAACT       Neuron  taylor2020      Pan-1
# 1806-ST-1-AAACCTGAGGTAGCCA       Neuron  taylor2020      Pan-1
# Empty DataFrame
# Columns: []
# Index: [WBGene00014450, WBGene00014451, WBGene00010957]

# %%
## let's remove genes with less than 20 counts across all samples
mincounts = 20
nremoved = np.sum(adata.X.sum(0) < mincounts)
print('Removing ', nremoved, ' genes with less than ', mincounts, 'counts')
adata = adata[:,(adata.X.sum(0) > mincounts)]
adata
# Out:
# Removing  28395  genes with less than  20 counts
# View of AnnData object with n_obs × n_vars = 100955 × 18454
#     obs: 'dropbox_id', 'counts', 'experiment_code', 'cell_type', 'tissue', 'study', 'experiment'

# %% [markdown]
# ## Define and train the model

# %% [markdown]
# We now create the model and the trainer object. We train the model and output model likelihood every epoch.
#
# If a pre-trained model already exist in the save_path then load the same model rather than re-training it. This is particularly useful for large datasets.

# %%
adata.obs
# Out:
#                            dropbox_id  counts experiment_code  \
# 1806-ST-1-AAACCTGAGAGACGAA  1806-ST-1      65           Pan-1
# 1806-ST-1-AAACCTGAGGTAAACT  1806-ST-1     367           Pan-1
# 1806-ST-1-AAACCTGAGGTAGCCA  1806-ST-1    1792           Pan-1
# 1806-ST-1-AAACCTGAGTAACCCT  1806-ST-1    1229           Pan-1
# 1806-ST-1-AAACCTGAGTACGCGA  1806-ST-1    1401           Pan-1
# ...                               ...     ...             ...
# 4170-ST-1-TTTGTTGCACTATCCC  4170-ST-1    2356    ceh-28_dat-1
# 4170-ST-1-TTTGTTGGTGGATCAG  4170-ST-1    1382    ceh-28_dat-1
# 4170-ST-1-TTTGTTGGTTTCGTTT  4170-ST-1     614    ceh-28_dat-1
# 4170-ST-1-TTTGTTGTCAGCCCAG  4170-ST-1     209    ceh-28_dat-1
# 4170-ST-1-TTTGTTGTCCATTCAT  4170-ST-1    2108    ceh-28_dat-1
#
#                                             cell_type           tissue  \
# 1806-ST-1-AAACCTGAGAGACGAA                Unannotated      Unannotated
# 1806-ST-1-AAACCTGAGGTAAACT                        AVF           Neuron
# 1806-ST-1-AAACCTGAGGTAGCCA                        AVH           Neuron
# 1806-ST-1-AAACCTGAGTAACCCT                        RIA           Neuron
# 1806-ST-1-AAACCTGAGTACGCGA                        AUA           Neuron
# ...                                               ...              ...
# 4170-ST-1-TTTGTTGCACTATCCC  Body_wall_muscle_anterior  Muscle_mesoderm
# 4170-ST-1-TTTGTTGGTGGATCAG                        PLN           Neuron
# 4170-ST-1-TTTGTTGGTTTCGTTT        Gonadal_sheath_cell     Reproductive
# 4170-ST-1-TTTGTTGTCAGCCCAG               Uterine_cell     Reproductive
# 4170-ST-1-TTTGTTGTCCATTCAT                        AVH           Neuron
#
#                                  study    experiment
# 1806-ST-1-AAACCTGAGAGACGAA  taylor2020         Pan-1
# 1806-ST-1-AAACCTGAGGTAAACT  taylor2020         Pan-1
# 1806-ST-1-AAACCTGAGGTAGCCA  taylor2020         Pan-1
# 1806-ST-1-AAACCTGAGTAACCCT  taylor2020         Pan-1
# 1806-ST-1-AAACCTGAGTACGCGA  taylor2020         Pan-1
# ...                                ...           ...
# 4170-ST-1-TTTGTTGCACTATCCC  taylor2020  ceh-28_dat-1
# 4170-ST-1-TTTGTTGGTGGATCAG  taylor2020  ceh-28_dat-1
# 4170-ST-1-TTTGTTGGTTTCGTTT  taylor2020  ceh-28_dat-1
# 4170-ST-1-TTTGTTGTCAGCCCAG  taylor2020  ceh-28_dat-1
# 4170-ST-1-TTTGTTGTCCATTCAT  taylor2020  ceh-28_dat-1
#
# [100955 rows x 7 columns]

# %%
## set up the adata with scvi 

adata.layers["counts"] = adata.X.copy() # preserve counts
scvi.model.SCVI.setup_anndata(adata, layer="counts", batch_key='experiment')

# %%
## train the model
## for this dataset 10 epochs is sufficient 
## with a GPU each epoch should take < 60s

### DEFINE MODEL
model = scvi.model.SCVI(adata,
                        n_hidden=128,
                        n_layers=2,
                        gene_likelihood='nb',
                        dispersion='gene-batch'
                        )

# MODEL TRAINING
model.train(check_val_every_n_epoch =1,
            accelerator='auto',
            max_epochs = 50,
            plan_kwargs={'lr':1e-3})
# Out:
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Training:   0%|          | 0/50 [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=50` reached.

# %%
# plot the training/test scores to see if the model finished training, if not do more epochs
train_test_results = model.history['elbo_train']
train_test_results['elbo_validation'] = model.history['elbo_validation']
train_test_results.plot(logy=True)
display(train_test_results)
plt.show()
# Out:
#         elbo_train elbo_validation
# epoch
# 0      2033.621704     1813.933838
# 1      1755.864868     1773.567139
# 2      1714.164551     1704.717041
# 3      1690.453613      1661.14917
# 4       1673.71521      1646.51062
# 5        1660.9198     1646.432495
# 6      1650.809448     1628.955322
# 7      1645.887939     1624.641846
# 8      1638.591064     1621.869385
# 9      1632.518066     1609.907959
# 10     1626.219482     1606.822266
# 11     1621.575806      1611.25708
# 12     1617.477173     1597.496582
# 13     1612.708984     1598.915039
# 14     1609.686523     1591.487427
# 15      1605.67981     1588.193604
# 16     1602.952148     1595.292114
# 17     1601.139038     1586.699463
# 18     1597.902588     1584.567993
# 19     1595.822144     1580.858154
# 20     1594.367554     1578.601074
# 21      1592.14978     1580.180664
# 22     1590.598389     1576.429321
# 23     1590.061035     1574.646484
# 24     1588.707642     1575.243042
# 25     1586.651855     1575.415527
# 26      1585.26355     1574.501099
# 27     1583.999268     1572.134033
# 28     1583.263794     1569.111572
# 29     1581.793213     1568.550903
# 30     1581.636719     1569.594849
# 31     1582.669067     1568.572876
# 32     1579.536377     1566.768066
# 33     1578.796631     1565.990601
# 34      1577.68103     1566.314209
# 35     1577.046997     1564.776001
# 36     1576.193848     1564.239136
# 37     1575.408081     1565.679688
# 38     1574.774292     1567.906372
# 39     1574.203125     1562.656494
# 40     1573.608887     1561.853516
# 41     1572.434448     1564.713135
# 42      1572.36145     1561.651367
# 43     1571.762573     1563.243286
# 44     1571.019043     1562.864136
# 45     1570.679443     1560.744263
# 46     1570.372925     1561.114868
# 47     1571.164673        1560.125
# 48     1569.327271     1561.444092
# 49     1568.646851     1558.736328

# %%
# this saves the scvi-tools models and the anndata file in a folder
# you only need to train the model once, then can always reload the same model to query it
model.save('cengen_50epochs', save_adata=True )
print('Saved model')
# Out:
# Saved model

# %%
## storing the latent space in the anndata allows interoperability with scanpy
adata.obsm["X_scVI"] =  model.get_latent_representation() # get latent
## the latent space by default is 10 dimensional, so it shape should be 10 x ncells
print(adata.obsm["X_scVI"].shape) 

## we can also retrieve the scvi expression rate, akin to normalized expression in other workflows
## however with 100k cells and 11k genes this crahses colab, you should use an instance with more RAM to do this
# adata.layers["scvi_expression_rate"] = model.get_normalized_expression(return_mean=True, return_numpy=True)
# Out:
# (100955, 10)

# %% [raw]
# cells_in_taylor2020=['Unannotated',  'AVF',  'AVH',  'RIA',  'AUA',  'Intestine',  'I5',  'AIZ',  'VB02',  'VD_DD',
#                      'RMD_LR',  'Epidermis',  'AVK',  'ASJ',  'ASG',  'AIM',  'Gonadal_sheath_cell',  'Unknown_non-neuronal_3',
#                      'VC',  'RIC',  'ADE',  'Seam_cell',  'AIN',  'RME_DV',  'AIB',  'SIA',  'ADA',  'Spermatheca',  'RIV',  'AIA',  'RIM',
#                      'CEP',  'AVJ',  'AVM',  'ASK',  'ASER',  'ALM',  'AS',  'AFD',  'PQR',  'BDU',  'RIG',  'RIB',  'ASI',  'RIR',  'SAB',  'PHB',
#                      'VB01',  'HSN',  'VC_4_5',  'AWC_ON',  'AVA',  'LUA',  'DA',  'IL2_DV',  'PVP',  'Unknown_non_neuronal',  'MI',  'VA',  'Coelomocyte',
#                      'ALA',  'ADL',  'AVE',  'PLN',  'Germline',  'SMD',  'Excretory_cell',  'DVB',  'RIF',  'URA',  'RMF',  'ASEL',  'SIB',  'Sperm',  'IL2_LR',
#                      'SDQ',  'RMG',  'AVL',  'VB',  'SAA',  'PVW',  'Body_wall_muscle',  'ALN',  'AVG',  'PVQ',  'FLP',  'AWA',  'AVB',  'ASH',  'AWC_OFF',  'DB',
#                      'AQR',  'IL1',  'PDE',  'PDA',  'RME_LR',  'XXX',  'RIS',  'MC',  'PHsh',  'M5',  'Arcade_cell',  'M2',  'Glia_1',  'PHC',  'RIH',  'Glia_2',  'Glia_5',
#                      'PHA',  'PLM',  'SMB',  'RMD_DV',  'RIP',  'RMH',  'RID',  'DVC',  'PVD',  'PVM',  'I4',  'PVC',  'AMso',  'URY',  'Excretory_gland_cell',  'URX',  'AIY',
#                      'BAG',  'AMsh',  'URB',  'AVD',  'Uterine_cell',  'I6',  'Vulval_cells',  'Vulval_muscle',  'PVN',  'Glia_3',  'AWB',  'M4',  'Anal_muscle',  'DB01',  'CEPsh',
#                      'I1',  'M3',  'Body_wall_muscle_anterior',  'Marginal_cell',  'PVT',  'Pharyngeal_gland_cell',  'Rectal_gland',  'ADF',  'hmc',  'Glia_4',  'Pharyngeal_muscle',
#                      'OLQ',  'Distal_tip_cell',  'Unknown_non_neuronal_2',  'PDB',  'DVA',  'RIV_stressed',  'PVR',  'DA9',  'VA12',  'Spermathecal-uterine_junction_or_uterine_toroid',
#                      'M1',  'OLL',  'CAN',  'SMD_stressed',  'I2',  'PHso',  'NSM',  'I3']

# %%
## Here we define a list of which cells we are interested in making swarm plots for 
## Because the swarmplot requires pairwise DE for all cell types in the dataset, and
## the CeNGEN dataset has 169, it can take a while to generate all the data
## it takes about 30 min per cell type to compute the DE, so we only do it for
## two cell types as an example




# cells_of_interest = ['ADE','ALN','PLN','AQR','CEP','FLP','OLQ','PDE','PHC','PQR','PVD','URB','URY']
## Olivia markers
cells_of_interest = ['ADE',  'ADF',  'ADL',  'AFD',  'AIM',  'AIN',  'ALA',  'ALM',  'ALN',  
              'AQR',  'ASER', 'ASEL',  'ASG',  'ASH',  'ASI',  'ASJ',  'ASK',  'AVE',  'AVG',  
              'AVH',  'AVK',  'AVM',  'AWA',  'AWB',  'AWC_OFF',  'AWC_ON',  
              'BAG',  'CAN',  'CEP',  'DVC',  'FLP',  'I1',  'I2',  'I6',  'IL1',  
              'IL2_DV', 'IL2_LR',  'LUA',  'M3',   'NSM',  'OLQ',  'PDA',  'PDE',  'PHA',  
              'PHB',  'PLM',  'PLN',  'PQR',  'PVC',  'PVD',  'PVM',  'PVQ',  'RIS',  
              'RMD_DV',  'RMG',  'URB',  'URX',  'URY']

#cells_of_interest = ['ASH']
studies_of_interest = ['taylor2020']

## let's check how many cells of the types we are interested in we have in total, per experiment
for celltype in cells_of_interest:
    print('\n=== Number of cells of type ', celltype, ' in each experiment ===')
    print(adata.obs[adata.obs.cell_type==celltype].experiment.value_counts())
# Out:
# === Number of cells of type  ADE  in each experiment ===
# experiment
# ceh-28_dat-1    282
# Pan-2            70
# ift-20           50
# Pan-1            48
# unc-53            2
# ceh-34            1
# cho-1_2           1
# eat-4             1
# tph-1_ceh-10      1
# unc-3             1
# cho-1_1           0
# acr-2             0
# nlp-13_ceh-2      0
# nmr-1             0
# unc-47_1          0
# unc-47_2          0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  ADF  in each experiment ===
# experiment
# tph-1_ceh-10    464
# ift-20          243
# Pan-2            16
# acr-2            12
# eat-4             7
# unc-3             3
# Pan-1             3
# cho-1_2           3
# cho-1_1           3
# ceh-34            2
# ceh-28_dat-1      1
# unc-53            1
# unc-86            1
# nlp-13_ceh-2      0
# nmr-1             0
# unc-47_1          0
# unc-47_2          0
# Name: count, dtype: int64
#
# === Number of cells of type  ADL  in each experiment ===
# experiment
# ift-20          512
# eat-4           330
# unc-3            28
# Pan-2            14
# unc-53           12
# acr-2            11
# Pan-1             8
# cho-1_2           7
# ceh-34            7
# cho-1_1           6
# unc-47_2          5
# ceh-28_dat-1      5
# unc-86            4
# nlp-13_ceh-2      3
# nmr-1             2
# tph-1_ceh-10      1
# unc-47_1          0
# Name: count, dtype: int64
#
# === Number of cells of type  AFD  in each experiment ===
# experiment
# eat-4           141
# Pan-2            57
# Pan-1            27
# unc-47_2          3
# unc-3             3
# ift-20            3
# nlp-13_ceh-2      2
# tph-1_ceh-10      2
# acr-2             2
# unc-53            2
# cho-1_2           1
# cho-1_1           1
# ceh-34            1
# nmr-1             0
# ceh-28_dat-1      0
# unc-47_1          0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  AIM  in each experiment ===
# experiment
# unc-86          231
# Pan-2           131
# unc-3            97
# Pan-1            84
# eat-4            76
# acr-2            20
# unc-47_2          8
# cho-1_1           7
# tph-1_ceh-10      7
# nlp-13_ceh-2      5
# nmr-1             5
# ceh-28_dat-1      3
# ift-20            3
# ceh-34            2
# cho-1_2           2
# unc-47_1          2
# unc-53            2
# Name: count, dtype: int64
#
# === Number of cells of type  AIN  in each experiment ===
# experiment
# unc-47_2        218
# unc-47_1         68
# Pan-2            64
# cho-1_1          55
# cho-1_2          40
# Pan-1            30
# unc-53           15
# tph-1_ceh-10     12
# unc-3             7
# acr-2             5
# ceh-28_dat-1      4
# unc-86            1
# nlp-13_ceh-2      1
# eat-4             1
# ceh-34            1
# nmr-1             0
# ift-20            0
# Name: count, dtype: int64
#
# === Number of cells of type  ALA  in each experiment ===
# experiment
# unc-53          113
# eat-4            74
# unc-3            16
# Pan-1            15
# Pan-2            10
# tph-1_ceh-10      4
# unc-47_1          2
# nlp-13_ceh-2      1
# ift-20            1
# cho-1_2           1
# acr-2             1
# nmr-1             0
# cho-1_1           0
# ceh-34            0
# ceh-28_dat-1      0
# unc-47_2          0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  ALM  in each experiment ===
# experiment
# ceh-28_dat-1    266
# eat-4           211
# unc-86          172
# Pan-1            44
# Pan-2            33
# unc-3            24
# unc-53           12
# ceh-34            2
# unc-47_1          2
# cho-1_1           1
# cho-1_2           1
# acr-2             1
# nlp-13_ceh-2      1
# tph-1_ceh-10      1
# nmr-1             0
# unc-47_2          0
# ift-20            0
# Name: count, dtype: int64
#
# === Number of cells of type  ALN  in each experiment ===
# experiment
# Pan-2           17
# Pan-1           11
# nlp-13_ceh-2     0
# unc-53           0
# unc-47_2         0
# unc-47_1         0
# unc-3            0
# tph-1_ceh-10     0
# nmr-1            0
# ift-20           0
# eat-4            0
# cho-1_2          0
# cho-1_1          0
# ceh-34           0
# ceh-28_dat-1     0
# acr-2            0
# unc-86           0
# Name: count, dtype: int64
#
# === Number of cells of type  AQR  in each experiment ===
# experiment
# ift-20          37
# eat-4           34
# unc-86          20
# Pan-2           16
# Pan-1           14
# ceh-28_dat-1     8
# ceh-34           1
# acr-2            1
# unc-3            1
# unc-53           1
# cho-1_1          0
# cho-1_2          0
# nlp-13_ceh-2     0
# nmr-1            0
# tph-1_ceh-10     0
# unc-47_1         0
# unc-47_2         0
# Name: count, dtype: int64
#
# === Number of cells of type  ASER  in each experiment ===
# experiment
# eat-4           214
# ift-20           41
# Pan-2            33
# Pan-1            26
# ceh-28_dat-1     11
# acr-2             8
# unc-47_2          7
# cho-1_1           6
# unc-3             6
# cho-1_2           4
# unc-53            3
# ceh-34            1
# tph-1_ceh-10      1
# nlp-13_ceh-2      0
# nmr-1             0
# unc-47_1          0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  ASEL  in each experiment ===
# experiment
# eat-4           94
# ift-20          57
# acr-2           15
# Pan-2           11
# unc-3            6
# Pan-1            6
# tph-1_ceh-10     2
# nlp-13_ceh-2     1
# nmr-1            1
# unc-47_2         1
# unc-86           1
# cho-1_2          0
# cho-1_1          0
# ceh-34           0
# ceh-28_dat-1     0
# unc-47_1         0
# unc-53           0
# Name: count, dtype: int64
#
# === Number of cells of type  ASG  in each experiment ===
# experiment
# nlp-13_ceh-2    931
# ift-20          431
# eat-4           301
# tph-1_ceh-10    297
# unc-3           122
# Pan-2           109
# Pan-1            49
# cho-1_1          12
# ceh-28_dat-1     12
# acr-2            11
# cho-1_2          10
# unc-47_2         10
# unc-53            6
# unc-86            5
# ceh-34            3
# nmr-1             3
# unc-47_1          0
# Name: count, dtype: int64
#
# === Number of cells of type  ASH  in each experiment ===
# experiment
# ift-20          324
# eat-4           183
# Pan-2            24
# Pan-1            19
# acr-2            14
# unc-53            7
# ceh-34            6
# ceh-28_dat-1      4
# tph-1_ceh-10      4
# unc-3             4
# unc-47_2          3
# cho-1_1           2
# cho-1_2           2
# nlp-13_ceh-2      1
# nmr-1             1
# unc-47_1          0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  ASI  in each experiment ===
# experiment
# ift-20          495
# unc-3           104
# Pan-2            65
# Pan-1            27
# acr-2            16
# nlp-13_ceh-2     11
# ceh-28_dat-1      9
# eat-4             6
# unc-47_2          6
# unc-53            6
# cho-1_1           4
# cho-1_2           3
# ceh-34            2
# nmr-1             2
# unc-86            2
# tph-1_ceh-10      1
# unc-47_1          0
# Name: count, dtype: int64
#
# === Number of cells of type  ASJ  in each experiment ===
# experiment
# ift-20          409
# ceh-28_dat-1    396
# Pan-2           144
# cho-1_1          91
# cho-1_2          87
# Pan-1            37
# eat-4            24
# acr-2            24
# unc-3            13
# ceh-34           10
# unc-47_2          9
# tph-1_ceh-10      8
# unc-53            7
# unc-86            5
# nlp-13_ceh-2      2
# nmr-1             0
# unc-47_1          0
# Name: count, dtype: int64
#
# === Number of cells of type  ASK  in each experiment ===
# experiment
# eat-4           347
# ift-20          199
# unc-3           108
# Pan-2           101
# Pan-1            57
# ceh-34           26
# acr-2            24
# unc-47_2          7
# unc-53            7
# nmr-1             6
# cho-1_1           5
# cho-1_2           5
# ceh-28_dat-1      4
# nlp-13_ceh-2      3
# tph-1_ceh-10      3
# unc-47_1          0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  AVE  in each experiment ===
# experiment
# nmr-1           751
# cho-1_1          61
# cho-1_2          55
# acr-2            51
# unc-3            15
# unc-53           15
# ceh-28_dat-1     13
# unc-47_2         11
# eat-4            10
# Pan-2             7
# Pan-1             5
# ift-20            5
# tph-1_ceh-10      5
# nlp-13_ceh-2      3
# ceh-34            1
# unc-86            1
# unc-47_1          0
# Name: count, dtype: int64
#
# === Number of cells of type  AVG  in each experiment ===
# experiment
# nmr-1           154
# acr-2           142
# unc-47_2         86
# Pan-2            21
# Pan-1            10
# unc-47_1          7
# unc-3             6
# cho-1_2           4
# unc-53            3
# cho-1_1           3
# nlp-13_ceh-2      3
# ceh-28_dat-1      2
# unc-86            1
# tph-1_ceh-10      1
# eat-4             0
# ceh-34            0
# ift-20            0
# Name: count, dtype: int64
#
# === Number of cells of type  AVH  in each experiment ===
# experiment
# Pan-2           105
# Pan-1            70
# unc-3            65
# unc-47_2         18
# acr-2            14
# ceh-34            7
# ceh-28_dat-1      6
# cho-1_2           6
# eat-4             6
# unc-53            5
# tph-1_ceh-10      5
# nlp-13_ceh-2      3
# ift-20            2
# unc-47_1          1
# nmr-1             1
# cho-1_1           1
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  AVK  in each experiment ===
# experiment
# Pan-2           595
# Pan-1           393
# unc-47_2         17
# unc-53            8
# tph-1_ceh-10      7
# ceh-28_dat-1      5
# unc-47_1          4
# eat-4             4
# cho-1_2           3
# unc-3             3
# unc-86            2
# nlp-13_ceh-2      2
# ceh-34            2
# acr-2             1
# nmr-1             0
# cho-1_1           0
# ift-20            0
# Name: count, dtype: int64
#
# === Number of cells of type  AVM  in each experiment ===
# experiment
# ceh-28_dat-1    90
# Pan-2           23
# eat-4           18
# Pan-1           17
# unc-86           5
# ceh-34           1
# acr-2            1
# unc-3            1
# cho-1_1          0
# cho-1_2          0
# nlp-13_ceh-2     0
# nmr-1            0
# tph-1_ceh-10     0
# unc-47_1         0
# unc-47_2         0
# unc-53           0
# ift-20           0
# Name: count, dtype: int64
#
# === Number of cells of type  AWA  in each experiment ===
# experiment
# ift-20          392
# Pan-2           107
# Pan-1            56
# acr-2            27
# eat-4            16
# unc-47_2         13
# ceh-34           12
# unc-3            11
# ceh-28_dat-1      7
# cho-1_1           7
# nmr-1             6
# tph-1_ceh-10      6
# unc-53            5
# cho-1_2           4
# unc-86            2
# nlp-13_ceh-2      1
# unc-47_1          1
# Name: count, dtype: int64
#
# === Number of cells of type  AWB  in each experiment ===
# experiment
# ift-20          131
# cho-1_1          43
# cho-1_2          40
# Pan-2            17
# unc-3            14
# acr-2            11
# Pan-1             5
# ceh-28_dat-1      5
# eat-4             4
# tph-1_ceh-10      2
# ceh-34            1
# nlp-13_ceh-2      1
# nmr-1             1
# unc-47_2          1
# unc-53            1
# unc-47_1          0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  AWC_OFF  in each experiment ===
# experiment
# eat-4           118
# ift-20           51
# Pan-2            26
# Pan-1            21
# acr-2             6
# nmr-1             4
# tph-1_ceh-10      3
# cho-1_2           2
# ceh-28_dat-1      2
# unc-47_2          2
# ceh-34            1
# cho-1_1           1
# unc-3             1
# unc-53            1
# nlp-13_ceh-2      0
# unc-47_1          0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  AWC_ON  in each experiment ===
# experiment
# eat-4           129
# ift-20           75
# Pan-2            20
# Pan-1            10
# ceh-28_dat-1      8
# acr-2             8
# unc-53            5
# unc-3             4
# tph-1_ceh-10      2
# unc-47_2          2
# cho-1_1           1
# nmr-1             1
# ceh-34            0
# cho-1_2           0
# nlp-13_ceh-2      0
# unc-47_1          0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  BAG  in each experiment ===
# experiment
# eat-4           150
# ift-20           19
# Pan-2            16
# unc-53            5
# Pan-1             5
# ceh-28_dat-1      4
# unc-3             4
# acr-2             4
# nmr-1             3
# unc-47_1          3
# unc-47_2          2
# nlp-13_ceh-2      1
# tph-1_ceh-10      1
# cho-1_1           0
# cho-1_2           0
# ceh-34            0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  CAN  in each experiment ===
# experiment
# tph-1_ceh-10    1818
# unc-86             5
# acr-2              2
# ceh-28_dat-1       2
# unc-53             1
# cho-1_2            1
# eat-4              1
# Pan-2              1
# unc-3              1
# unc-47_2           0
# unc-47_1           0
# Pan-1              0
# nmr-1              0
# nlp-13_ceh-2       0
# cho-1_1            0
# ceh-34             0
# ift-20             0
# Name: count, dtype: int64
#
# === Number of cells of type  CEP  in each experiment ===
# experiment
# ceh-28_dat-1    633
# ift-20          150
# Pan-1            47
# Pan-2            36
# acr-2             8
# cho-1_2           5
# unc-53            5
# cho-1_1           3
# eat-4             3
# nlp-13_ceh-2      3
# unc-3             3
# unc-47_2          3
# ceh-34            2
# tph-1_ceh-10      2
# unc-47_1          2
# unc-86            2
# nmr-1             0
# Name: count, dtype: int64
#
# === Number of cells of type  DVC  in each experiment ===
# experiment
# eat-4           141
# unc-3            12
# Pan-2             7
# Pan-1             4
# ceh-28_dat-1      4
# unc-47_2          2
# unc-47_1          2
# nlp-13_ceh-2      1
# tph-1_ceh-10      0
# unc-53            0
# ift-20            0
# nmr-1             0
# cho-1_2           0
# cho-1_1           0
# ceh-34            0
# acr-2             0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  FLP  in each experiment ===
# experiment
# Pan-1           39
# Pan-2           33
# eat-4           24
# ceh-28_dat-1    20
# unc-53           4
# unc-47_2         4
# tph-1_ceh-10     2
# unc-47_1         1
# unc-86           1
# cho-1_2          1
# cho-1_1          1
# nlp-13_ceh-2     0
# nmr-1            0
# unc-3            0
# ceh-34           0
# acr-2            0
# ift-20           0
# Name: count, dtype: int64
#
# === Number of cells of type  I1  in each experiment ===
# experiment
# acr-2           42
# ceh-34          37
# unc-86           7
# Pan-2            6
# Pan-1            3
# unc-3            2
# tph-1_ceh-10     1
# unc-47_2         1
# cho-1_1          0
# cho-1_2          0
# eat-4            0
# ceh-28_dat-1     0
# nlp-13_ceh-2     0
# nmr-1            0
# unc-47_1         0
# unc-53           0
# ift-20           0
# Name: count, dtype: int64
#
# === Number of cells of type  I2  in each experiment ===
# experiment
# eat-4           15
# ceh-34           7
# acr-2            2
# unc-53           2
# unc-86           1
# nlp-13_ceh-2     1
# tph-1_ceh-10     0
# unc-47_2         0
# unc-47_1         0
# unc-3            0
# Pan-1            0
# nmr-1            0
# Pan-2            0
# cho-1_2          0
# cho-1_1          0
# ceh-28_dat-1     0
# ift-20           0
# Name: count, dtype: int64
#
# === Number of cells of type  I6  in each experiment ===
# experiment
# eat-4           49
# Pan-2            6
# Pan-1            4
# unc-53           1
# unc-47_2         1
# ceh-34           1
# nmr-1            0
# unc-47_1         0
# unc-3            0
# tph-1_ceh-10     0
# ift-20           0
# nlp-13_ceh-2     0
# cho-1_2          0
# cho-1_1          0
# ceh-28_dat-1     0
# acr-2            0
# unc-86           0
# Name: count, dtype: int64
#
# === Number of cells of type  IL1  in each experiment ===
# experiment
# ift-20          25
# eat-4           10
# Pan-1            7
# unc-3            5
# Pan-2            3
# unc-86           3
# ceh-28_dat-1     1
# cho-1_2          1
# nmr-1            1
# unc-47_2         1
# unc-53           1
# ceh-34           0
# cho-1_1          0
# acr-2            0
# nlp-13_ceh-2     0
# tph-1_ceh-10     0
# unc-47_1         0
# Name: count, dtype: int64
#
# === Number of cells of type  IL2_DV  in each experiment ===
# experiment
# nlp-13_ceh-2    182
# unc-86          101
# ift-20           89
# cho-1_2          44
# cho-1_1          41
# Pan-2            28
# unc-3            28
# Pan-1            20
# unc-47_2         11
# eat-4             5
# acr-2             5
# nmr-1             3
# ceh-34            2
# ceh-28_dat-1      1
# tph-1_ceh-10      0
# unc-47_1          0
# unc-53            0
# Name: count, dtype: int64
#
# === Number of cells of type  IL2_LR  in each experiment ===
# experiment
# unc-86          92
# nlp-13_ceh-2    61
# ift-20          45
# unc-53          37
# Pan-2           21
# cho-1_2         20
# Pan-1           20
# cho-1_1         17
# acr-2            7
# unc-3            7
# eat-4            6
# unc-47_2         4
# ceh-28_dat-1     2
# tph-1_ceh-10     1
# ceh-34           0
# nmr-1            0
# unc-47_1         0
# Name: count, dtype: int64
#
# === Number of cells of type  LUA  in each experiment ===
# experiment
# eat-4           20
# Pan-2           18
# Pan-1           11
# ceh-28_dat-1    10
# unc-86           8
# unc-53           3
# cho-1_1          2
# cho-1_2          1
# acr-2            1
# nlp-13_ceh-2     1
# nmr-1            1
# unc-3            1
# ceh-34           0
# tph-1_ceh-10     0
# unc-47_1         0
# unc-47_2         0
# ift-20           0
# Name: count, dtype: int64
#
# === Number of cells of type  M3  in each experiment ===
# experiment
# eat-4           15
# ceh-34          11
# nlp-13_ceh-2    11
# Pan-2            9
# tph-1_ceh-10     4
# Pan-1            1
# unc-53           1
# unc-47_2         0
# unc-47_1         0
# unc-3            0
# ift-20           0
# nmr-1            0
# cho-1_2          0
# cho-1_1          0
# ceh-28_dat-1     0
# acr-2            0
# unc-86           0
# Name: count, dtype: int64
#
# === Number of cells of type  NSM  in each experiment ===
# experiment
# nlp-13_ceh-2    510
# tph-1_ceh-10     50
# ceh-34            6
# acr-2             4
# unc-53            1
# cho-1_1           1
# Pan-1             0
# unc-47_2          0
# unc-47_1          0
# unc-3             0
# ift-20            0
# nmr-1             0
# Pan-2             0
# eat-4             0
# cho-1_2           0
# ceh-28_dat-1      0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  OLQ  in each experiment ===
# experiment
# eat-4           39
# ift-20          26
# ceh-28_dat-1     3
# unc-47_1         2
# unc-3            2
# Pan-2            2
# unc-86           2
# cho-1_1          2
# cho-1_2          1
# tph-1_ceh-10     1
# ceh-34           1
# acr-2            1
# unc-47_2         1
# unc-53           1
# Pan-1            1
# nlp-13_ceh-2     0
# nmr-1            0
# Name: count, dtype: int64
#
# === Number of cells of type  PDA  in each experiment ===
# experiment
# unc-53          6
# cho-1_1         5
# cho-1_2         5
# Pan-2           3
# Pan-1           1
# acr-2           1
# tph-1_ceh-10    0
# unc-47_2        0
# unc-47_1        0
# unc-3           0
# ift-20          0
# nmr-1           0
# nlp-13_ceh-2    0
# eat-4           0
# ceh-34          0
# ceh-28_dat-1    0
# unc-86          0
# Name: count, dtype: int64
#
# === Number of cells of type  PDE  in each experiment ===
# experiment
# ceh-28_dat-1    69
# Pan-2           19
# ift-20           9
# Pan-1            8
# unc-3            2
# nlp-13_ceh-2     1
# unc-47_1         1
# unc-86           1
# ceh-34           0
# cho-1_1          0
# cho-1_2          0
# eat-4            0
# acr-2            0
# nmr-1            0
# tph-1_ceh-10     0
# unc-47_2         0
# unc-53           0
# Name: count, dtype: int64
#
# === Number of cells of type  PHA  in each experiment ===
# experiment
# eat-4           78
# ift-20          77
# Pan-2            6
# Pan-1            6
# unc-86           3
# cho-1_2          1
# ceh-28_dat-1     1
# unc-47_2         1
# unc-53           1
# ceh-34           0
# cho-1_1          0
# acr-2            0
# nlp-13_ceh-2     0
# nmr-1            0
# tph-1_ceh-10     0
# unc-3            0
# unc-47_1         0
# Name: count, dtype: int64
#
# === Number of cells of type  PHB  in each experiment ===
# experiment
# eat-4           159
# ift-20           43
# Pan-2             9
# unc-3             3
# Pan-1             3
# unc-86            3
# cho-1_1           2
# cho-1_2           2
# unc-53            2
# ceh-28_dat-1      1
# unc-47_2          1
# ceh-34            0
# nlp-13_ceh-2      0
# nmr-1             0
# tph-1_ceh-10      0
# acr-2             0
# unc-47_1          0
# Name: count, dtype: int64
#
# === Number of cells of type  PLM  in each experiment ===
# experiment
# ceh-28_dat-1    239
# unc-86           89
# eat-4            24
# Pan-2            10
# Pan-1             5
# unc-3             4
# unc-53            3
# unc-47_1          1
# cho-1_1           0
# cho-1_2           0
# ceh-34            0
# acr-2             0
# nlp-13_ceh-2      0
# nmr-1             0
# tph-1_ceh-10      0
# unc-47_2          0
# ift-20            0
# Name: count, dtype: int64
#
# === Number of cells of type  PLN  in each experiment ===
# experiment
# ceh-28_dat-1    99
# Pan-2           71
# Pan-1           45
# unc-3           21
# cho-1_2         18
# unc-53          16
# cho-1_1         15
# unc-86           3
# eat-4            3
# nlp-13_ceh-2     2
# unc-47_1         2
# unc-47_2         2
# nmr-1            1
# ceh-34           1
# tph-1_ceh-10     0
# acr-2            0
# ift-20           0
# Name: count, dtype: int64
#
# === Number of cells of type  PQR  in each experiment ===
# experiment
# eat-4           21
# unc-86          16
# Pan-2           13
# Pan-1            8
# nlp-13_ceh-2     5
# ceh-28_dat-1     2
# ift-20           2
# tph-1_ceh-10     1
# unc-3            1
# unc-53           1
# ceh-34           0
# cho-1_1          0
# cho-1_2          0
# acr-2            0
# nmr-1            0
# unc-47_1         0
# unc-47_2         0
# Name: count, dtype: int64
#
# === Number of cells of type  PVC  in each experiment ===
# experiment
# unc-53          208
# nmr-1           127
# ceh-28_dat-1     10
# unc-3             9
# Pan-2             9
# Pan-1             5
# cho-1_1           5
# cho-1_2           5
# unc-47_1          2
# unc-86            1
# nlp-13_ceh-2      0
# tph-1_ceh-10      0
# eat-4             0
# ceh-34            0
# unc-47_2          0
# acr-2             0
# ift-20            0
# Name: count, dtype: int64
#
# === Number of cells of type  PVD  in each experiment ===
# experiment
# Pan-1           14
# eat-4           14
# Pan-2           12
# ceh-28_dat-1    10
# unc-86           7
# unc-53           3
# acr-2            1
# unc-3            1
# cho-1_1          0
# cho-1_2          0
# ceh-34           0
# nlp-13_ceh-2     0
# nmr-1            0
# tph-1_ceh-10     0
# unc-47_1         0
# unc-47_2         0
# ift-20           0
# Name: count, dtype: int64
#
# === Number of cells of type  PVM  in each experiment ===
# experiment
# ceh-28_dat-1    49
# Pan-2            5
# unc-53           4
# Pan-1            3
# acr-2            2
# nmr-1            0
# unc-47_2         0
# unc-47_1         0
# unc-3            0
# tph-1_ceh-10     0
# ift-20           0
# nlp-13_ceh-2     0
# eat-4            0
# cho-1_2          0
# cho-1_1          0
# ceh-34           0
# unc-86           0
# Name: count, dtype: int64
#
# === Number of cells of type  PVQ  in each experiment ===
# experiment
# eat-4           197
# Pan-1            42
# Pan-2            33
# ceh-28_dat-1     31
# unc-3            28
# unc-53           18
# nmr-1             2
# nlp-13_ceh-2      2
# ift-20            2
# acr-2             2
# cho-1_2           1
# cho-1_1           1
# tph-1_ceh-10      1
# unc-47_2          1
# ceh-34            0
# unc-47_1          0
# unc-86            0
# Name: count, dtype: int64
#
# === Number of cells of type  RIS  in each experiment ===
# experiment
# unc-47_2        26
# unc-47_1        17
# Pan-2            6
# Pan-1            5
# nlp-13_ceh-2     1
# unc-3            1
# unc-53           0
# tph-1_ceh-10     0
# nmr-1            0
# ift-20           0
# eat-4            0
# cho-1_2          0
# cho-1_1          0
# ceh-34           0
# ceh-28_dat-1     0
# acr-2            0
# unc-86           0
# Name: count, dtype: int64
#
# === Number of cells of type  RMD_DV  in each experiment ===
# experiment
# cho-1_1         149
# cho-1_2         139
# eat-4           129
# unc-3            52
# unc-53           41
# Pan-2            23
# nmr-1            19
# acr-2            16
# unc-47_2         16
# Pan-1            15
# ceh-28_dat-1      6
# unc-47_1          3
# unc-86            3
# nlp-13_ceh-2      3
# ceh-34            2
# ift-20            2
# tph-1_ceh-10      1
# Name: count, dtype: int64
#
# === Number of cells of type  RMG  in each experiment ===
# experiment
# Pan-1           25
# Pan-2           24
# unc-3           15
# acr-2            7
# ceh-28_dat-1     6
# unc-53           3
# unc-86           3
# eat-4            2
# nlp-13_ceh-2     2
# cho-1_2          1
# nmr-1            1
# cho-1_1          1
# ceh-34           1
# ift-20           1
# tph-1_ceh-10     0
# unc-47_1         0
# unc-47_2         0
# Name: count, dtype: int64
#
# === Number of cells of type  URB  in each experiment ===
# experiment
# unc-86          50
# unc-3           17
# Pan-1            9
# cho-1_2          5
# Pan-2            5
# cho-1_1          4
# ceh-28_dat-1     3
# eat-4            3
# acr-2            3
# unc-53           2
# nlp-13_ceh-2     1
# unc-47_1         1
# unc-47_2         1
# ift-20           1
# ceh-34           0
# nmr-1            0
# tph-1_ceh-10     0
# Name: count, dtype: int64
#
# === Number of cells of type  URX  in each experiment ===
# experiment
# nlp-13_ceh-2    218
# unc-47_2         67
# ift-20           29
# ceh-28_dat-1     28
# unc-86           26
# cho-1_1          22
# cho-1_2          15
# unc-3             6
# Pan-2             5
# Pan-1             5
# unc-53            2
# eat-4             1
# nmr-1             1
# acr-2             1
# ceh-34            0
# tph-1_ceh-10      0
# unc-47_1          0
# Name: count, dtype: int64
#
# === Number of cells of type  URY  in each experiment ===
# experiment
# eat-4           69
# Pan-1            5
# Pan-2            5
# unc-86           2
# ift-20           1
# ceh-34           0
# cho-1_1          0
# cho-1_2          0
# ceh-28_dat-1     0
# acr-2            0
# nlp-13_ceh-2     0
# nmr-1            0
# tph-1_ceh-10     0
# unc-3            0
# unc-47_1         0
# unc-47_2         0
# unc-53           0
# Name: count, dtype: int64

# %% [markdown]
# # Make swarm plots

# %%
### This checks how many cells of each type of interest are found in each study
### If there are cells in at least  ~20 cell in each study then it's fine to proceed with
### the differential expression and create the swarm plots
### In this example notebook we only have the CeNGEN dataset, aka taylor2020
print('\n Checking how many `cells_of_interest` are present in each study...')
for study in studies_of_interest:
    print('\n \n 🔹 🔹 🔹 🔹 🔹 🔹 🔹 🔹 Cell counts for:', study, ' 🔹 🔹 🔹 🔹 🔹 🔹 🔹 🔹   ')
    adata_study=adata[adata.obs.study==study]
    for cell_type_1 in cells_of_interest:  
        cell_idx1 = adata_study[adata_study.obs['cell_type'] == cell_type_1].obs.index
        ncells1=len(cell_idx1)
        if ncells1==0:
            ### if the cell type of interest is not present it will print a warning message with the red emojis
            print(' 🛑 🛑 🛑 \t  0 \t', cell_type_1, ' \t cells in ', study, ' \t 🛑 🛑 🛑 ')
            continue
        print(' ✅ ✅ ✅ \t ',ncells1,'\t',  cell_type_1, ' \t cells in ', study, ' \t ✅ ✅ ✅ ')
# Out:
#  Checking how many `cells_of_interest` are present in each study...
#
#
#  🔹 🔹 🔹 🔹 🔹 🔹 🔹 🔹 Cell counts for: taylor2020  🔹 🔹 🔹 🔹 🔹 🔹 🔹 🔹
#  ✅ ✅ ✅ 	  457 	 ADE  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  759 	 ADF  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  955 	 ADL  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  245 	 AFD  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  685 	 AIM  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  522 	 AIN  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  238 	 ALA  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  771 	 ALM  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  28 	 ALN  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  133 	 AQR  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  361 	 ASER  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  195 	 ASEL  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  2312 	 ASG  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  598 	 ASH  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  759 	 ASI  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  1266 	 ASJ  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  902 	 ASK  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  1009 	 AVE  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  443 	 AVG  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  315 	 AVH  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  1046 	 AVK  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  156 	 AVM  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  673 	 AWA  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  277 	 AWB  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  239 	 AWC_OFF  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  265 	 AWC_ON  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  217 	 BAG  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  1832 	 CAN  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  907 	 CEP  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  173 	 DVC  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  130 	 FLP  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  99 	 I1  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  28 	 I2  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  62 	 I6  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  58 	 IL1  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  560 	 IL2_DV  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  340 	 IL2_LR  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  77 	 LUA  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  52 	 M3  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  572 	 NSM  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  85 	 OLQ  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  21 	 PDA  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  110 	 PDE  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  174 	 PHA  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  228 	 PHB  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  375 	 PLM  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  299 	 PLN  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  70 	 PQR  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  381 	 PVC  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  62 	 PVD  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  63 	 PVM  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  361 	 PVQ  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  56 	 RIS  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  619 	 RMD_DV  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  92 	 RMG  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  105 	 URB  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  426 	 URX  	 cells in  taylor2020  	 ✅ ✅ ✅
#  ✅ ✅ ✅ 	  82 	 URY  	 cells in  taylor2020  	 ✅ ✅ ✅

# %%
## perform DE against ALL cells for swarm plot
## for each cell_type we store the results in the allde dictionary
## each entry of the allde dict is a dataframe with the pairwise DE results 

allde={}

for study in studies_of_interest:
    print('\n \n 🔹 🔹 🔹 🔹 🔹 🔹 🔹 🔹 Cell counts for:', study, ' 🔹 🔹 🔹 🔹 🔹 🔹 🔹 🔹   ')
    adata_study=adata[adata.obs.study==study]
    for cell_type_1 in cells_of_interest:  
        
        cell_idx1 = adata_study[adata_study.obs['cell_type'] == cell_type_1].obs.index
        ncells1=len(cell_idx1)
        if ncells1==0:
            print(' 🛑 🛑 🛑 \t  0 \t', cell_type_1, ' \t cells in ', study, ' \t SKIPPING... 🛑 🛑 🛑 ')
            continue
        print(' ✅ ✅ ✅ \t ',ncells1,'\t',  cell_type_1, ' \t cells in dataset ', study, ' \t  ✅ ✅ ✅ ')
        
        cell_types_in_study = np.sort(adata[adata.obs.study==study].obs.cell_type.unique())
        print('Performing DE for', len(cell_types_in_study), ' distinct cell types in this dataset... ')
        
        allde[cell_type_1+study]=pd.DataFrame()  
        for cell_type_2 in tqdm(cell_types_in_study):

            cell_idx2 = adata_study[adata_study.obs['cell_type'] == cell_type_2].obs.index
            ncells2=len(cell_idx2)
            # print(ncells2, ' \t ' +  str(cell_type_2) +  '  \t \t  \t vs  ', ncells1, cell_type_1, ' in ', study)

            if cell_type_1==cell_type_2:
#                 print(cell_type_1, cell_type_2, '...skipping...')
                continue
            ###### DE CHANGE ############
            de = model.differential_expression(
                idx1 = adata.obs.index.isin(cell_idx1), 
                idx2 = adata.obs.index.isin(cell_idx2), 
                mode='change',
                silent=True
                )
            de['comparison']=cell_type_2
            # allde[cell_type_1+study] = allde[cell_type_1+study].append(de) # OLD 2021 CODE
            allde[cell_type_1+study] = pd.concat([de, allde[cell_type_1+study]], ignore_index=False) # NEW 2025 CODE FIXED
            
        ### Save DE results in one folder per cell type per study    
        savename = 'DE_results_' + cell_type_1+'_'+ study
#         if not os.path.exists(savename): os.makedirs(savename)    
        allde[cell_type_1+study].to_csv(savename+'.csv')
        savename2= 'globalde'+celltype+'taylor2020.csv'
        allde[cell_type_1+study].to_csv(savename2)
# Out:
#
#  🔹 🔹 🔹 🔹 🔹 🔹 🔹 🔹 Cell counts for: taylor2020  🔹 🔹 🔹 🔹 🔹 🔹 🔹 🔹
#  ✅ ✅ ✅ 	  457 	 ADE  	 cells in dataset  taylor2020  	  ✅ ✅ ✅
# Performing DE for 169  distinct cell types in this dataset...
# 100%|█████████████████████████████████████████| 169/169 [07:47<00:00,  2.77s/it]
#  ✅ ✅ ✅ 	  759 	 ADF  	 cells in dataset  taylor2020  	  ✅ ✅ ✅
# Performing DE for 169  distinct cell types in this dataset...
# 100%|█████████████████████████████████████████| 169/169 [07:43<00:00,  2.74s/it]
#  ✅ ✅ ✅ 	  955 	 ADL  	 cells in dataset  taylor2020  	  ✅ ✅ ✅
# Performing DE for 169  distinct cell types in this dataset...
# 100%|█████████████████████████████████████████| 169/169 [07:50<00:00,  2.79s/it]
#  ✅ ✅ ✅ 	  245 	 AFD  	 cells in dataset  taylor2020  	  ✅ ✅ ✅
# Performing DE for 169  distinct cell types in this dataset...
#  28%|███████████▋                              | 47/169 [02:06<05:35,  2.75s/it]

# %%
# downloads a file that maps gene names to gene id and puts that in a dataframe
# the genemaps is used to add the gene names
# !wget -nc https://raw.githubusercontent.com/Munfred/worm-markers/master/worm_gene_name_id.csv
genemaps = pd.read_csv('./worm_gene_name_id.csv', index_col=1)
name2id=genemaps.set_index('gene_name')
name2id['gene_id']=genemaps.index

# %%
# finally combine all this information to make the swarm plots
# we use plotly to make the interactive scatter plot, to learn how to tweak 
# the plot see the documentation at 
# https://plotly.com/python/line-and-scatter/
globalde=allde
dedfs = globalde
for study in studies_of_interest:
    # makes two plots, one with top 50 and one with top 100, you can add more genes if needed
    for n_top_selection in [50]:
        print('\n \n 🔹 🔹 🔹 🔹 🔹 🔹 🔹 🔹 Cell counts for:', study, ' 🔹 🔹 🔹 🔹 🔹 🔹 🔹 🔹   ')
        # if you have multiple studies in the anndata object, select only one
        adata_study=adata[adata.obs.study==study]
        # then loop through each cell of interst
        for cell_type_1 in cells_of_interest:  
            cell_idx1 = adata_study[adata_study.obs['cell_type'] == cell_type_1].obs.index
            ncells1=len(cell_idx1)
            if ncells1==0:
                print(' 🛑 🛑 🛑 \t  0 \t', cell_type_1, ' \t cells in ', study, ' \t SKIPPING... 🛑 🛑 🛑 ')
                continue
            print(' ✅ ✅ ✅ \t ',ncells1,'\t',  cell_type_1, ' \t cells in ', study, ' \t MAKING SWARM PLOT FOR... ✅ ✅ ✅ ')
            cell_types_in_study = np.sort(adata[adata.obs.study==study].obs.cell_type.unique())
            print(len(cell_types_in_study), ' CELL TYPES ')

            # sort display order by median log fold change
            # select positive lfc
            sel=dedfs[cell_type_1+study][dedfs[cell_type_1+study].lfc_mean>0].copy()
            sel['gene_id']=sel.index
            # sort by p value, select top n
            sel = sel.sort_values(by='proba_not_de', ascending=True).head(n_top_selection)

            # if you want you can extra genes to be included in the plot with the list
            # list_of_genes_to_color, they can be highlighted as red
            # uncommeting the other blow below
            # markersdf = dedfs[cell_type_1+study][dedfs[cell_type_1+study].index.isin(list_of_genes_to_color)].copy()    

            sel['gene_id']=sel.index
            sel_genes=sel['gene_id']

            # now create the plotly plot
            # `data` contains each gene to plot
            data = []    
            for gene_id, _gene_id in sel_genes[::-1].items():
                gene_name=genemaps.loc[gene_id]['gene_name']

                dedf=allde[cell_type_1+study][allde[cell_type_1+study].index==gene_id].copy()
                color = 'rgb(0, 0, 0)'
                
                # add a list of gene ids to a list called `list_of_genes_to_color` and
                # uncomment the line below to highlight those genes in red
                #if gene_id in list_of_genes_to_color: 
                #    color = 'rgb(255, 0, 0)'

                trace = go.Box(
                 x=-np.round(dedf['lfc_mean'],3), boxpoints = 'all', pointpos = 0
                , marker = dict(color = color)
                , line = dict(color = 'rgba(0,0,0,0)')
                , fillcolor = 'rgba(0,0,0,0)'
                , opacity=1
                , marker_size=4  
                , name = gene_name  + ' \t \t \t expression rate = 10^' + str(np.round(np.log10(dedf['scale1'][0]),1)) #+ ' | p=' + f"{sel[sel.gene_id==gene_id]['proba_not_de'][0]:.1E}"
                , hoverinfo='text'
                , text= 'Cell type: ' + dedf['comparison'].values +'<br>' +'Gene: ' + gene_name + '<br>'+ dedf['comparison'].values + ' expression: 10^'+pd.Series(np.round(np.log10(dedf['scale2'].values),1).astype(str))
                , customdata=cell_type_1 + ' expression rate: 10^'+ pd.Series(np.round(np.log10(dedf['scale1'].values),1).astype(str)) +"<br>log2 fold change: " 
                    + np.round(dedf['lfc_median'].values,1).astype(str)
                , hovertemplate='%{text}<br>%{customdata} ' +
                                ' ' +'<extra></extra>'
                )
                data.append(trace)
            title= ' Relative log fold change in expression of top ' +str(n_top_selection) + ' ' + cell_type_1 + ' specific genes in ' + study
            layout = go.Layout(title=title
                             # uncomment the line below to fix the plot width
                             # , width=750
                               , height=n_top_selection*23
                              )
            fig = go.Figure(data, layout)
            fig.update_layout(showlegend=False, template='none', xaxis_title="log2 fold change relative to expression in "+cell_type_1,)
            fig.update_xaxes(tickangle=90, tickfont=dict( color='black', size=12),automargin=True)
            fig.update_yaxes(automargin=True)
            fig.update_layout(hovermode="closest")

            # create a folder and save the topN plots on that folder
            folder_name='top'+str(n_top_selection)
            html_title='./'+folder_name+'/' + cell_type_1+study + '_top'+str(n_top_selection)+'genes_swarmplot.html'
            print(title)
            if not os.path.exists(folder_name): 
                os.makedirs(folder_name)

            # comment the line below to not save
            fig.write_html(html_title)

            # this will show the plotly plot on jupyter
            fig.show()
print('DONE!')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Control warnings
import warnings; warnings.simplefilter('ignore')

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

import torch
import anndata
from tqdm import tqdm
from umap import UMAP
from openTSNE import TSNE
import scanpy as sc 
import plotly.express as px
import plotly.graph_objects as go
from IPython.display import Image
import scvi
print('You are using scvi-tools version:',scvi.__version__)


from matplotlib import cm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import itertools

# %%
# downloads a file that maps gene names to gene id and puts that in a dataframe
# the genemaps is used to add the gene names
# !wget -nc https://raw.githubusercontent.com/Munfred/worm-markers/master/worm_gene_name_id.csv
genemaps = pd.read_csv('./worm_gene_name_id.csv', index_col=1)
name2id=genemaps.set_index('gene_name')
name2id['gene_id']=genemaps.index

# %%
ntop=25
for celltype in cells_of_interest:
    print(celltype)

    topde=pd.read_csv('globalde'+celltype+'taylor2020.csv')
    topde

    colors = itertools.cycle(["yellowgreen", 'cornflowerblue'])


    n_genes_selected=25

    global_de=pd.read_csv('globalde'+celltype+'taylor2020.csv')
    # select only negative logfold change genes
    negative_lfc_genes=global_de[global_de['lfc_mean']>0]
    #within negative lfc genes, sort by p value, then reindex them with lowest p value being ranked first 
    topgenes=negative_lfc_genes.sort_values(by='proba_not_de')['gene_id'][:ntop].iloc[::-1].reset_index(drop=True)
    topgenes.index += 1 
    # topgenes=pd.Series(sel.index)

    pairwise_de=pd.read_csv('DE_results_'+celltype+'_taylor2020.csv', index_col=0)
    pairwise_de
    # pairwise_de_selection = pairwise_de[pairwise_de['gene_id'].isin(topgenes)]
    pairwise_de_selection = pairwise_de[pairwise_de.index.isin(topgenes)]
    pairwise_de_selection

    # topgenes=sel.index
    de_topgenes=global_de[global_de['gene_id'].isin(topgenes)]

    # definitions for the axes
    left, width = 0.1, 0.65
    bottom, height = 0.1, 0.65
    spacing = 0.0

    rect_scatter = [left, bottom, width, height]
    rect_left = [ -left  + spacing, bottom, 0.2, height]
    rect_right = [left + width + spacing, bottom, 0.2, height]

    # start with a square Figure
    fig = plt.figure(figsize=(8, 12), dpi=100)

    ax = fig.add_axes(rect_scatter)
    ax_left = fig.add_axes(rect_left, sharey=ax)
    ax_right = fig.add_axes(rect_right, sharey=ax)

    ax.axes.yaxis.set_visible(False)
    ax_left.axes.yaxis.set_visible(False)
    ax_right.axes.yaxis.set_visible(False)


    for rank, gene_id in topgenes.items():
        color=next(colors)
        # gene_expression_values = pairwise_de_selection[pairwise_de_selection['gene_id']==gene_id]
        gene_expression_values = pairwise_de_selection[pairwise_de_selection.index==gene_id]

        ax.scatter(-gene_expression_values['lfc_mean'], [rank]*len(gene_expression_values), c=color, alpha=0.6, s = 30, edgecolors='none')
        expression=de_topgenes.query('gene_id==@gene_id')['scale1'].values
        pvalue=de_topgenes.query('gene_id==@gene_id')['proba_not_de'].values
        ax_right.barh(rank,expression , color=color)
        ax_left.barh(rank,pvalue , color=color)
        ax_left.text(0, rank-0.18,'  '+ genemaps.loc[gene_id][0])
    #     ax_right.text(ax_right.get_xlim()[0], rank,' foo')

    ax.title.set_text('Log2 fold change relative expression in ' +celltype +' \n of top '+ str(n_genes_selected) + ' DE genes')
    ax_left.title.set_text('DE p-value')
    ax_right.title.set_text(celltype + ' expression')

    ax_left.grid(True, ls = '--')
    ax_right.grid(True, ls = '--')
    # ax_left.set_xscale('log')
    ax_right.set_xscale('log')
    ax.set_xlim(left=-9, right = 9)
    # ax.set_xlabel('Log2 fold change relative to cell expression in ' +celltype)
    # ax_left.set_xlabel('common label')
    # ax_right.set_xlabel('common label')
    # ax_left.xaxis.set_major_locator(plt.MaxNLocator(1))
    # ax_right.xaxis.set_major_locator(plt.MaxNLocator(1))
    ax_left.xaxis.set_minor_locator(plt.MaxNLocator(2))
    ax_right.xaxis.set_minor_locator(plt.MaxNLocator(2))
    ax_left.set_xlim(left=0, right = 0.01)
    ax_right.set_xlim(left=10e-6, right = 10e-2)

    ax.grid(True, ls = '--')
    ax.axvline(x=0, color='k', linestyle='--')
    plt.savefig('./'+celltype+'_nice_swarmplot.png', dpi=150)
    plt.show()
